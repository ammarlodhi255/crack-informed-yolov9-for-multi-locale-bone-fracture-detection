# %%
# !python train_dual.py --patience 50 --workers 8 --device 0 --batch 32 --data data/alb.yaml --img 640 --cfg models/detect/yolov9-c.yaml --name albumentation_v9c --hyp hyp.scratch-highcopy.yaml --min-items 0 --epochs 500 --close-mosaic 15
# Out:
# train_dual: weights=, cfg=models/detect/yolov9-c.yaml, data=data/alb.yaml, hyp=hyp.scratch-highcopy.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=albumentation_v9c, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# ...

# %%
# !python val_dual.py --data data/alb.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/albumentation_v9c/weights/best.pt" --name albumentation_v9c_validation

# %%
# !python val_dual.py --task 'test' --data data/alb.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/albumentation_v9c/weights/best.pt" --name albumentation_v9c
