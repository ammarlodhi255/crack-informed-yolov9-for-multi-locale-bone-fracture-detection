# %%
# !python train_dual.py --weights "/cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOLOV9/runs/train/e_crack2/weights/best.pt" --workers 8 --device 0 --data data/data.yaml --batch 32 --img 640 --epochs 500 --cfg models/detect/yolov9-e.yaml --patience 50 --name e_reassess_twice_adamw --optimizer 'AdamW' --hyp hyp.scratch-highcopy.yaml --min-items 0 --close-mosaic 15
# Out:
# train_dual: weights=/cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOLOV9/runs/train/e_crack2/weights/best.pt, cfg=models/detect/yolov9-e.yaml, data=data/data.yaml, hyp=hyp.scratch-highcopy.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=AdamW, sync_bn=False, workers=8, project=runs/train, name=e_reassess_twice_adamw, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# ...

# %%
# !python val_dual.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/e_reassess_twice_adamw/weights/best.pt" --name e_reassess_twice_adamw_validation
# Out:
# val_dual: data=data/data.yaml, weights=['runs/train/e_reassess_twice_adamw/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=e_reassess_twice_adamw_validation, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68549356 parameters, 0 gradients, 240.7 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         82         91      0.677      0.549      0.586      0.273
#              fractured         82         91      0.677      0.549      0.586      0.273
# ...

# %%
# !python val_dual.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/e_reassess_twice_adamw/weights/best.pt" --name e_reassess_twice_adamw
# Out:
# val_dual: data=data/data.yaml, weights=['runs/train/e_reassess_twice_adamw/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=e_reassess_twice_adamw, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68549356 parameters, 0 gradients, 240.7 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         61         67       0.71      0.438      0.501      0.189
#              fractured         61         67       0.71      0.438      0.501      0.189
# ...
