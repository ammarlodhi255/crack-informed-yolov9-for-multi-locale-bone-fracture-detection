# %%
# !wandb login

# %%
# !python train_dual.py --weights "/cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOLOV9/runs/train/yolov9-c4/weights/best.pt" --workers 8 --device 0 --batch 32 --data data/data.yaml --img 640 --cfg models/detect/yolov9-c.yaml --name fracture_pretrained --hyp hyp.scratch-high.yaml --min-items 0 --epochs 500 --close-mosaic 15
# Out:
# train_dual: weights=/cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOLOV9/runs/train/yolov9-c4/weights/best.pt, cfg=models/detect/yolov9-c.yaml, data=data/data.yaml, hyp=hyp.scratch-high.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=fracture_pretrained, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-PCIE-40GB, 40338MiB)
#
# ...

# %%
# !python val_dual.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_pretrained_c/weights/best.pt" --name fracture_pretrained_c
# Out:
# val_dual: data=data/data.yaml, weights=['runs/train/fracture_pretrained_c/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=fracture_pretrained_c, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-c summary: 604 layers, 50700588 parameters, 0 gradients, 236.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         61         67      0.795      0.464      0.529      0.227
#              fractured         61         67      0.795      0.464      0.529      0.227
# ...

# %% [markdown]
# #### Without Pre-training

# %%
# !python train_dual.py --weights "" --workers 8 --device 0 --batch 32 --data data/data.yaml --img 640 --cfg models/detect/yolov9-c.yaml --name fracture_default --hyp hyp.scratch-high.yaml --min-items 0 --epochs 500 --close-mosaic 15
# Out:
# train_dual: weights=, cfg=models/detect/yolov9-c.yaml, data=data/data.yaml, hyp=hyp.scratch-high.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=fracture_default, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-PCIE-40GB, 40338MiB)
#
# ...

# %%
# !python val_dual.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_default_c/weights/best.pt" --name fracture_default_c
# Out:
# val_dual: data=data/data.yaml, weights=['runs/train/fracture_default_c/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=fracture_default_c, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-c summary: 604 layers, 50700588 parameters, 0 gradients, 236.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         61         67      0.849      0.478      0.517      0.186
#              fractured         61         67      0.849      0.478      0.517      0.186
# ...

# %% [markdown]
# #### Results on the Validation Set in Order of "With Pretraining" and "Without Pretraining"

# %%
# !python val_dual.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_pretrained_c/weights/best.pt" --name fracture_pretrained_c_validation
# Out:
# val_dual: data=data/data.yaml, weights=['runs/train/fracture_pretrained_c/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=fracture_pretrained_c_validation, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-c summary: 604 layers, 50700588 parameters, 0 gradients, 236.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         82         91      0.867      0.527      0.583      0.273
#              fractured         82         91      0.867      0.527      0.583      0.273
# ...

# %%
# !python val_dual.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_default_c/weights/best.pt" --name fracture_default_c_validation
# Out:
# val_dual: data=data/data.yaml, weights=['runs/train/fracture_default_c/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=fracture_default_c_validation, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-c summary: 604 layers, 50700588 parameters, 0 gradients, 236.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         82         91      0.788      0.505       0.53      0.239
#              fractured         82         91      0.788      0.505       0.53      0.239
# ...
