# %%
# !wandb login

# %%
# !python train.py --weights "runs/train/gelan_e_crack/weights/best.pt" --workers 8 --device 0  --patience 50 --batch 32 --data data/data.yaml --img 640 --cfg models/detect/gelan-e.yaml --name fracture_pretrained_gelan_e --hyp hyp.scratch-high.yaml --min-items 0 --epochs 500 --close-mosaic 15
# Out:
# train: weights=runs/train/gelan_e_crack/weights/best.pt, cfg=models/detect/gelan-e.yaml, data=data/data.yaml, hyp=hyp.scratch-high.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=fracture_pretrained_gelan_e, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-PCIE-40GB, 40338MiB)
#
# ...

# %%
# !python val.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_pretrained_gelan_e/weights/best.pt" --name pretrained_gelan_e
# Out:
# val: data=data/data.yaml, weights=['runs/train/fracture_pretrained_gelan_e/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=pretrained_gelan_e, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-PCIE-40GB, 40338MiB)
#
# Fusing layers...
# gelan-e summary: 690 layers, 57285782 parameters, 0 gradients, 188.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         61         67      0.755      0.463      0.506        0.2
#              fractured         61         67      0.755      0.463      0.506        0.2
# ...

# %% [markdown]
# #### Without Pre-training

# %%
# !python train.py --weights "" --workers 8 --device 0 --batch 16 --patience 50 --data data/data.yaml --img 640 --cfg models/detect/gelan-e.yaml --name fracture_default_gelan_e --hyp hyp.scratch-high.yaml --min-items 0 --epochs 500 --close-mosaic 15
# Out:
# train: weights=, cfg=models/detect/gelan-e.yaml, data=data/data.yaml, hyp=hyp.scratch-high.yaml, epochs=500, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=fracture_default_gelan_e, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (Tesla V100-PCIE-32GB, 32501MiB)
#
# ...

# %%
# !python val.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_default_gelan_e/weights/best.pt" --name default_gelan_e
# Out:
# val: data=data/data.yaml, weights=['runs/train/fracture_default_gelan_e/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=default_gelan_e, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-PCIE-40GB, 40338MiB)
#
# Fusing layers...
# gelan-e summary: 690 layers, 57285782 parameters, 0 gradients, 188.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         61         67      0.736      0.448      0.496      0.174
#              fractured         61         67      0.736      0.448      0.496      0.174
# ...

# %% [markdown]
# #### Results on the Validation Set in Order of "With Pretraining" and "Without Pretraining"

# %%
# !python val.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_pretrained_gelan_e/weights/best.pt" --name pretrained_gelan_e_validation
# Out:
# val: data=data/data.yaml, weights=['runs/train/fracture_pretrained_gelan_e/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=pretrained_gelan_e_validation, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-PCIE-40GB, 40338MiB)
#
# Fusing layers...
# gelan-e summary: 690 layers, 57285782 parameters, 0 gradients, 188.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         82         91      0.694      0.597      0.632        0.3
#              fractured         82         91      0.694      0.597      0.632        0.3
# ...

# %%
# !python val.py --data data/data.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/fracture_default_gelan_e/weights/best.pt" --name default_gelan_e_validation
# Out:
# val: data=data/data.yaml, weights=['runs/train/fracture_default_gelan_e/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=default_gelan_e_validation, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-PCIE-40GB, 40338MiB)
#
# Fusing layers...
# gelan-e summary: 690 layers, 57285782 parameters, 0 gradients, 188.6 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         82         91       0.77      0.505      0.587      0.262
#              fractured         82         91       0.77      0.505      0.587      0.262
# ...
