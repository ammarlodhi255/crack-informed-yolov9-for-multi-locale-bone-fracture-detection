# %%
# !python train.py --weights "runs/train/gelan_crack2/weights/best.pt" --workers 8 --device 0 --patience 50 --batch 32 --data data/aug.yaml --img 640 --cfg models/detect/gelan.yaml --name aug_pretrained_gelan --hyp hyp.scratch-high.yaml --min-items 0 --epochs 500 --close-mosaic 15
# Out:
# train: weights=runs/train/gelan_crack2/weights/best.pt, cfg=models/detect/gelan.yaml, data=data/aug.yaml, hyp=hyp.scratch-high.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=aug_pretrained_gelan, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# ...

# %%
# !python val.py --data data/aug.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/aug_pretrained_gelan/weights/best.pt" --name aug_pretrained_gelan_validation
# Out:
# val: data=data/aug.yaml, weights=['runs/train/aug_pretrained_gelan/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=aug_pretrained_gelan_validation, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# gelan summary: 372 layers, 31192406 parameters, 0 gradients, 116.8 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         82         91      0.743      0.604      0.605      0.291
#              fractured         82         91      0.743      0.604      0.605      0.291
# ...

# %%
# !python val.py --data data/aug.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/aug_pretrained_gelan/weights/best.pt" --name aug_pretrained_gelan
# Out:
# val: data=data/aug.yaml, weights=['runs/train/aug_pretrained_gelan/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=aug_pretrained_gelan, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# gelan summary: 372 layers, 31192406 parameters, 0 gradients, 116.8 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         61         67      0.693      0.507      0.512      0.202
#              fractured         61         67      0.693      0.507      0.512      0.202
# ...
