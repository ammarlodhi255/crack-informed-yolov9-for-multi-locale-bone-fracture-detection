# %%
# !python train_dual.py --resume '/cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOLOV9/runs/train/albumentation_v9e/weights/last.pt' --patience 50 --workers 8 --device 0 --batch 32 --data data/alb.yaml --img 640 --cfg models/detect/yolov9-e.yaml --name albumentation_v9e --hyp hyp.scratch-highcopy.yaml --min-items 0 --epochs 500 --close-mosaic 15
# Out:
# train_dual: weights=, cfg=models/detect/yolov9-e.yaml, data=data/alb.yaml, hyp=hyp.scratch-highcopy.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=/cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOLOV9/runs/train/albumentation_v9e/weights/last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=albumentation_v9e, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=50, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# ...

# %%
# !python val_dual.py --data data/alb.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/albumentation_v9e/weights/best.pt" --name albumentation_v9e_validation
# Out:
# val_dual: data=data/alb.yaml, weights=['runs/train/albumentation_v9e/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=albumentation_v9e_validation, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68549356 parameters, 0 gradients, 240.7 GFLOPs
# val: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOL
#                  Class     Images  Instances          P          R      mAP50
#                    all         82         91       0.49      0.396      0.372      0.124
#              fractured         82         91       0.49      0.396      0.372      0.124
# ...

# %%
# !python val_dual.py --task 'test' --data data/alb.yaml --img 640 --batch 32 --conf 0.001 --iou 0.5 --weights "runs/train/albumentation_v9e/weights/best.pt" --name albumentation_v9e_test
# Out:
# val_dual: data=data/alb.yaml, weights=['runs/train/albumentation_v9e/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=albumentation_v9e_test, exist_ok=False, half=False, dnn=False, min_items=0
# YOLO 🚀 2024-3-22 Python-3.12.2 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100 80GB PCIe, 81050MiB)
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68549356 parameters, 0 gradients, 240.7 GFLOPs
# test: Scanning /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YO
# test: New cache created: /cluster/home/ammaa/Downloads/Ammars/Models/Fracture_Detection/YOLOV9/data/Albumentation/test.cache
#                  Class     Images  Instances          P          R      mAP50
#                    all         61         67      0.454      0.299      0.254     0.0879
# ...
